# %%
# %cd /content/drive/MyDrive/4995-DL-Project/VRGNet
# Out:
# /content/drive/MyDrive/4995-DL-Project/VRGNet

# %%
# !python for_syn/test_interpolation.py --data_path "../Rain100L/rainy" --gt_path "../Rain100L/norain" --netED "for_syn/syn100lmodels/ED_state_700.pt"  --save_patch "./interpolation_results/test_data/rain100L/crop_patch_256/" --save_inputfake "./interpolation_results/generated_data/rain100L/input_fake_256" --save_rainfake "./interpolation_results/generated_data/rain100L/rain_fake_256" --gpu_id 0
# Out:
# Loading model ...
#
# rain-097.png
# rain-088.png
# rain-089.png
# rain-093.png
# rain-096.png
# rain-098.png
# rain-090.png
# rain-091.png
# rain-094.png
# rain-092.png
# rain-095.png
# rain-087.png
# rain-085.png
# rain-086.png
# rain-100.png
# rain-099.png
# rain-084.png
# rain-080.png
# rain-082.png
# rain-068.png
# rain-069.png
# rain-071.png
# rain-072.png
# rain-073.png
# rain-064.png
# rain-065.png
# rain-081.png
# rain-083.png
# rain-066.png
# rain-075.png
# rain-067.png
# rain-076.png
# rain-077.png
# rain-078.png
# rain-070.png
# rain-079.png
# rain-074.png
# rain-057.png
# rain-060.png
# rain-050.png
# rain-051.png
# rain-056.png
# rain-055.png
# rain-063.png
# rain-044.png
# rain-059.png
# rain-049.png
# rain-054.png
# rain-045.png
# rain-058.png
# rain-047.png
# rain-061.png
# rain-062.png
# rain-053.png
# rain-046.png
# rain-048.png
# rain-052.png
# rain-043.png
# rain-032.png
# rain-042.png
# rain-026.png
# rain-025.png
# rain-030.png
# rain-031.png
# rain-027.png
# ...

# %%
import matplotlib.pyplot as plt
from PIL import Image

images = [
          '/content/drive/MyDrive/4995-DL-Project/VRGNet/interpolation_results/generated_data/rain100L/gt_crops/rain-097.png',
          '/content/drive/MyDrive/4995-DL-Project/VRGNet/interpolation_results/generated_data/rain100L/rain_fake_256/0_0.0_rainfake.png',
          '/content/drive/MyDrive/4995-DL-Project/VRGNet/interpolation_results/generated_data/rain100L/input_fake_256/0_0.0_O0fake.png'
]

images = [Image.open(image) for image in images]

f, ax = plt.subplots(1,3, figsize=(16,16))
ax[0].imshow(images[0])
ax[0].axis('off')

ax[1].imshow(images[1])
ax[1].axis('off')

ax[2].imshow(images[2])
ax[2].axis('off')
# Out:
# (-0.5, 63.5, 63.5, -0.5)
